# %% [markdown]
# Module de Statistiques

# %%
import stats_temp as stats
import matplotlib.pyplot as plt

dossier = "simu_01_06_2026_23_58_44"
start_gen = 1
end_gen = 20
gen_step = 1

nbRows = 1
nbCols = 1

# %%
fig, ax = plt.subplots(nbRows, nbCols, figsize=(6 * nbCols, 6 * nbRows))
stats.histo_clusters(fig, ax, end_gen, dossier, start_gen, gen_step)
# Out:
# Chargement des données...
# Lecture fichiers: 100%|██████████| 20/20 [00:00<00:00, 133.70gen/s]
# Propagation des couleurs: 100%|██████████| 190000/190000 [00:02<00:00, 89210.55dist/s]
# Nombre total de familles distinctes : 114
#   → 23 famille(s) outlier(s) détectée(s) sur 114 (IQR×1.5 : [0.694, 0.757])
